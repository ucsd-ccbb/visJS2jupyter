# %% [markdown]
# # Test the functionality of visJS_2_jupyter
#
# ------------
#
# Authors: Brin Rosenthal (sbrosenthal@ucsd.edu), Mikayla Webster (m1webste@ucsd.edu)
#
# -----------

# %% [markdown]
# ## Import packages

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

import networkx as nx
import numpy as np
import pandas as pd

import sys
sys.path.append('../src/')
import visJS_module

import imp
imp.reload(visJS_module)
# Out:
# <module 'visJS_module' from '../src/visJS_module.py'>

# %% [markdown]
# # Draw a simple network with default parameters

# %%
G = nx.connected_watts_strogatz_graph(100,5,.2)
nodes = G.nodes()
edges = G.edges()
pos = nx.spring_layout(G)

# %%
nodes_dict = [{"id":n} for n in nodes]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges

edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "title":'test'} for i in range(len(edges))]

visJS_module.visjs_network(nodes_dict,edges_dict,time_stamp=0)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "dot", "degree": 3.0, "title": 0, "color": "#8BA8D3", "border_width": 0, "id": 0}, {"node_shape": "dot", "degree": 3.0, "title": 1, "color": "#8BA8D3", "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 3.0, "title": 2, "color": "#8BA8D3", "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 3.0, "title": 3, "color": "#8BA8D3", "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 3.0, "title": 4, "color": "#8BA8D3", "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 3.0, "title": 5, "color": "#8BA8D3", "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 3.0, "title": 6, "color": "#8BA8D3", "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 3.0, "title": 7, "color": "#8BA8D3", "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 3.0, "title": 8, "color": "#8BA8D3", "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 3.0, "title": 9, "color": "#8BA8D3", "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 3.0, "title": 10, "color": "#8BA8D3", "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 3.0, "title": 11, "color": "#8BA8D3", "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 3.0, "title": 12, "color": "#8BA8D3", "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 3.0, "title": 13, "color": "#8BA8D3", "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 3.0, "title": 14, "color": "#8BA8D3", "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 3.0, "title": 15, "color": "#8BA8D3", "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 3.0, "title": 16, "color": "#8BA8D3", "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 3.0, "title": 17, "color": "#8BA8D3", "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 3.0, "title": 18, "color": "#8BA8D3", "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 3.0, "title": 19, "color": "#8BA8D3", "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 3.0, "title": 20, "color": "#8BA8D3", "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 3.0, "title": 21, "color": "#8BA8D3", "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 3.0, "title": 22, "color": "#8BA8D3", "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 3.0, "title": 23, "color": "#8BA8D3", "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 3.0, "title": 24, "color": "#8BA8D3", "border_width": 0, "id": 24}, {"node_shape": "dot", "degree": 3.0, "title": 25, "color": "#8BA8D3", "border_width": 0, "id": 25}, {"node_shape": "dot", "degree": 3.0, "title": 26, "color": "#8BA8D3", "border_width": 0, "id": 26}, {"node_shape": "dot", "degree": 3.0, "title": 27, "color": "#8BA8D3", "border_width": 0, "id": 27}, {"node_shape": "dot", "degree": 3.0, "title": 28, "color": "#8BA8D3", "border_width": 0, "id": 28}, {"node_shape": "dot", "degree": 3.0, "title": 29, "color": "#8BA8D3", "border_width": 0, "id": 29}, {"node_shape": "dot", "degree": 3.0, "title": 30, "color": "#8BA8D3", "border_width": 0, "id": 30}, {"node_shape": "dot", "degree": 3.0, "title": 31, "color": "#8BA8D3", "border_width": 0, "id": 31}, {"node_shape": "dot", "degree": 3.0, "title": 32, "color": "#8BA8D3", "border_width": 0, "id": 32}, {"node_shape": "dot", "degree": 3.0, "title": 33, "color": "#8BA8D3", "border_width": 0, "id": 33}, {"node_shape": "dot", "degree": 3.0, "title": 34, "color": "#8BA8D3", "border_width": 0, "id": 34}, {"node_shape": "dot", "degree": 3.0, "title": 35, "color": "#8BA8D3", "border_width": 0, "id": 35}, {"node_shape": "dot", "degree": 3.0, "title": 36, "color": "#8BA8D3", "border_width": 0, "id": 36}, {"node_shape": "dot", "degree": 3.0, "title": 37, "color": "#8BA8D3", "border_width": 0, "id": 37}, {"node_shape": "dot", "d ...

# %% [markdown]
# # Add some style to the nodes and edges

# %%
nodes_dict = [{"id":n,"degree":G.degree(n),
              "color":"red",
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges

edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "title":'test'} for i in range(len(edges))]

visJS_module.visjs_network(nodes_dict,edges_dict,time_stamp=1)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"node_shape": "dot", "degree": 4, "title": 0, "color": "red", "y": -130.00298587764703, "x": -460.18944310319671, "border_width": 0, "id": 0}, {"node_shape": "dot", "degree": 5, "title": 1, "color": "red", "y": -114.51898018198885, "x": -363.76533574093736, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 4, "title": 2, "color": "red", "y": -180.4833139764466, "x": -593.61943847694306, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 4, "title": 3, "color": "red", "y": -237.08814342993, "x": -546.24691022361355, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 3, "title": 4, "color": "red", "y": -350.78523241941633, "x": -668.31923417424957, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 4, "title": 5, "color": "red", "y": -406.80519221781827, "x": -642.16146300679668, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 5, "title": 6, "color": "red", "y": -480.35875408081819, "x": -460.11378422718934, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 4, "title": 7, "color": "red", "y": -438.96919475746967, "x": -554.68858230843421, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 6, "title": 8, "color": "red", "y": -332.05238234638097, "x": -347.39388609204195, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 4, "title": 9, "color": "red", "y": -517.84099210055865, "x": -528.14464183722566, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 4, "title": 10, "color": "red", "y": -402.75205821014822, "x": -426.27949914703305, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 3, "title": 11, "color": "red", "y": -706.50412009693389, "x": -582.6023664229607, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 4, "title": 12, "color": "red", "y": -632.38320516823433, "x": -528.49325556701524, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 4, "title": 13, "color": "red", "y": -708.33611185217092, "x": -411.19166892623394, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 4, "title": 14, "color": "red", "y": -573.90390865923575, "x": -468.42855752437828, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 4, "title": 15, "color": "red", "y": -322.5887519997076, "x": -430.54713088489331, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 4, "title": 16, "color": "red", "y": -495.84945641226153, "x": -374.85881491644187, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 4, "title": 17, "color": "red", "y": -398.94505184430926, "x": -357.46696622025831, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 4, "title": 18, "color": "red", "y": -397.83016092251415, "x": -209.02578352679708, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 4, "title": 19, "color": "red", "y": -197.64981801547404, "x": -359.64635366775485, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 4, "title": 20, "color": "red", "y": -104.55978717106562, "x": -165.03298369655147, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 4, "title": 21, "color": "red", "y": 3.0517651777211823, "x": -254.87492227062043, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 5, "title": 22, "color": "red", "y": 209.45667376812861, "x": 45.280464790128583, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 4, "title": 23, "color": "red", "y": 156.4803729083059, "x": -96.022169733097343, "border_width": 0, "id": 23}, {"node_shape": "dot", "degree": 4, "title": 24, "color": "red", "y": 274.40089483069187, "x": 52.753466094637758, "border_width": 0, "id": 24}, {"node_shape": "dot", "degree": 5, "title": 25, "color": "red", "y": 181.73753666158018, "x": -148.25386719158473, "border_width": 0, "id": 25}, {"node_shape": "dot", "degree": 3, "title" ...

# %% [markdown]
# # Map node attributes to properties
#
# - To map node attributes to properties, simply add the property to the graph as a node-attribute, and use the return_node_to_color function

# %%
# add a node attributes to color-code by
cc = nx.clustering(G)
degree = G.degree()
bc = nx.betweenness_centrality(G)
nx.set_node_attributes(G,'clustering_coefficient',cc)
nx.set_node_attributes(G,'degree',degree)
nx.set_node_attributes(G,'betweenness_centrality',bc)

# %%
node_to_color = visJS_module.return_node_to_color(G,field_to_map='betweenness_centrality',cmap=mpl.cm.spring_r,alpha = 1,
                                                 color_max_frac = .9,color_min_frac = .1)

nodes_dict = [{"id":n,"color":node_to_color[n],
               "degree":nx.degree(G,n),
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

visJS_module.visjs_network(nodes_dict,edges_dict,time_stamp=2,
                          node_size_multiplier=5,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='blue',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#8BADD3',
                          edge_width=3,
                          max_velocity=15)

# visJS_module.visjs_network(nodes_dict,edges_dict,
#                             node_highlight_color="black",
#                             node_hover_color = 'orange',
#                             node_size_transform='Math.sqrt',
#                             node_size_multiplier=2,
#                             node_border_width=0,
#                             hover = False,
#                             label_field='id',
#                             edge_width=3,
#                             hover_connected_edges = False,
#                             physics_enabled=False,
#                             min_velocity=.5,
#                             max_velocity=16,
#                             draw_threshold=100,
#                             min_label_size=50,
#                             max_label_size=50,
#                             max_visible=10,
#                             edge_label_size=50,
#                             graph_title = graph_title)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file2"];    frame.runVis([{"node_shape": "dot", "degree": 4, "title": 0, "color": "rgba(256, 205, 50, 1)", "y": -130.00298587764703, "x": -460.18944310319671, "border_width": 0, "id": 0}, {"node_shape": "dot", "degree": 5, "title": 1, "color": "rgba(256, 177, 78, 1)", "y": -114.51898018198885, "x": -363.76533574093736, "border_width": 0, "id": 1}, {"node_shape": "dot", "degree": 4, "title": 2, "color": "rgba(256, 214, 41, 1)", "y": -180.4833139764466, "x": -593.61943847694306, "border_width": 0, "id": 2}, {"node_shape": "dot", "degree": 4, "title": 3, "color": "rgba(256, 179, 76, 1)", "y": -237.08814342993, "x": -546.24691022361355, "border_width": 0, "id": 3}, {"node_shape": "dot", "degree": 3, "title": 4, "color": "rgba(256, 214, 41, 1)", "y": -350.78523241941633, "x": -668.31923417424957, "border_width": 0, "id": 4}, {"node_shape": "dot", "degree": 4, "title": 5, "color": "rgba(256, 210, 45, 1)", "y": -406.80519221781827, "x": -642.16146300679668, "border_width": 0, "id": 5}, {"node_shape": "dot", "degree": 5, "title": 6, "color": "rgba(256, 164, 91, 1)", "y": -480.35875408081819, "x": -460.11378422718934, "border_width": 0, "id": 6}, {"node_shape": "dot", "degree": 4, "title": 7, "color": "rgba(256, 214, 41, 1)", "y": -438.96919475746967, "x": -554.68858230843421, "border_width": 0, "id": 7}, {"node_shape": "dot", "degree": 6, "title": 8, "color": "rgba(256, 88, 167, 1)", "y": -332.05238234638097, "x": -347.39388609204195, "border_width": 0, "id": 8}, {"node_shape": "dot", "degree": 4, "title": 9, "color": "rgba(256, 209, 46, 1)", "y": -517.84099210055865, "x": -528.14464183722566, "border_width": 0, "id": 9}, {"node_shape": "dot", "degree": 4, "title": 10, "color": "rgba(256, 150, 105, 1)", "y": -402.75205821014822, "x": -426.27949914703305, "border_width": 0, "id": 10}, {"node_shape": "dot", "degree": 3, "title": 11, "color": "rgba(256, 214, 41, 1)", "y": -706.50412009693389, "x": -582.6023664229607, "border_width": 0, "id": 11}, {"node_shape": "dot", "degree": 4, "title": 12, "color": "rgba(256, 207, 48, 1)", "y": -632.38320516823433, "x": -528.49325556701524, "border_width": 0, "id": 12}, {"node_shape": "dot", "degree": 4, "title": 13, "color": "rgba(256, 196, 59, 1)", "y": -708.33611185217092, "x": -411.19166892623394, "border_width": 0, "id": 13}, {"node_shape": "dot", "degree": 4, "title": 14, "color": "rgba(256, 204, 51, 1)", "y": -573.90390865923575, "x": -468.42855752437828, "border_width": 0, "id": 14}, {"node_shape": "dot", "degree": 4, "title": 15, "color": "rgba(256, 195, 60, 1)", "y": -322.5887519997076, "x": -430.54713088489331, "border_width": 0, "id": 15}, {"node_shape": "dot", "degree": 4, "title": 16, "color": "rgba(256, 214, 41, 1)", "y": -495.84945641226153, "x": -374.85881491644187, "border_width": 0, "id": 16}, {"node_shape": "dot", "degree": 4, "title": 17, "color": "rgba(256, 207, 48, 1)", "y": -398.94505184430926, "x": -357.46696622025831, "border_width": 0, "id": 17}, {"node_shape": "dot", "degree": 4, "title": 18, "color": "rgba(256, 161, 94, 1)", "y": -397.83016092251415, "x": -209.02578352679708, "border_width": 0, "id": 18}, {"node_shape": "dot", "degree": 4, "title": 19, "color": "rgba(256, 171, 84, 1)", "y": -197.64981801547404, "x": -359.64635366775485, "border_width": 0, "id": 19}, {"node_shape": "dot", "degree": 4, "title": 20, "color": "rgba(256, 157, 98, 1)", "y": -104.55978717106562, "x": -165.03298369655147, "border_width": 0, "id": 20}, {"node_shape": "dot", "degree": 4, "title": 21, "color": "rgba(256, 180, 75, 1)", "y": 3.0517651777211823, "x": -254.87492227062043, "border_width": 0, "id": 21}, {"node_shape": "dot", "degree": 5, "title": 22, "color": "rgba(256, 129, 126, 1)", "y": 209.45667376812861, "x": 45.280464790128583, "border_width": 0, "id": 22}, {"node_shape": "dot", "degree": 4, "title": 23, "color": "r ...
